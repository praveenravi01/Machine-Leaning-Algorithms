# %% [markdown]
# <a href="https://colab.research.google.com/github/praveenravi01/Machine-Leaning-Algorithms/blob/main/Statistics_1_on_Restaurant_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
ds=pd.read_csv("/content/Restaurant.csv")

# %%
ds.head()
# Out:
#        DATE   TIME  INVOICE_NO     ITEM  QUANTITY  RATE  SUB_TOTAL  AMOUNT  \
# 0  01.10.23  23.40         174  PAROTTA       4.0  18.0       72.0     NaN
# 1  01.10.23  23.40         174  OMLETTE       2.0  18.0       36.0   108.0
# 2  01.10.23  23.36         173     DOSA       3.0  20.0       60.0     NaN
# 3  01.10.23  23.36         173  PAROTTA       2.0  18.0       36.0     NaN
# 4  01.10.23  23.36         173   KALAKI       1.0  15.0       15.0   111.0
#
#    DAY
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1

# %%
# to take the data based on the date
dt=ds[ds["DATE"]=="01.10.23"]

# %%
dt.head()
# Out:
#        DATE   TIME  INVOICE_NO     ITEM  QUANTITY  RATE  SUB_TOTAL  AMOUNT  \
# 0  01.10.23  23.40         174  PAROTTA       4.0  18.0       72.0     NaN
# 1  01.10.23  23.40         174  OMLETTE       2.0  18.0       36.0   108.0
# 2  01.10.23  23.36         173     DOSA       3.0  20.0       60.0     NaN
# 3  01.10.23  23.36         173  PAROTTA       2.0  18.0       36.0     NaN
# 4  01.10.23  23.36         173   KALAKI       1.0  15.0       15.0   111.0
#
#    DAY
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1

# %%
# To find the bill of 117
dt["AMOUNT"].mean()
# Out:
# np.float64(184.2280701754386)

# %%
inv=ds[ds["INVOICE_NO"]==117]

# %%
inv.head()
# Out:
#         DATE   TIME  INVOICE_NO             ITEM  QUANTITY   RATE  SUB_TOTAL  \
# 80  01.10.23  20.29         117       GHEE ROAST       2.0   50.0      100.0
# 81  01.10.23  20.29         117        EGG ROAST       2.0   50.0      100.0
# 82  01.10.23  20.29         117  CHICKEN NOODLES       1.0  100.0      100.0
# 83  01.10.23  20.29         117   CHILLI CHICKEN       1.0  100.0      100.0
# 84  01.10.23  20.29         117      COOL DRINKS       2.0   15.0       30.0
#
#     AMOUNT  DAY
# 80     NaN    1
# 81     NaN    1
# 82     NaN    1
# 83     NaN    1
# 84   430.0    1

# %%
inv["AMOUNT"].sum()
# Out:
# np.float64(625.0)

# %%
a=ds["ITEM"]
b=ds["AMOUNT"]
plt.bar(a,b)
# Out:
# <BarContainer object of 531 artists>

# %%
# To find the top sold item of 5
a=ds.groupby("ITEM")["SUB_TOTAL"].sum().sort_values(ascending=False).head(5)
# ds_sorted=ds.sort_values(by="SUB_TOTAL", ascending=False)

# %%
b=ds.groupby("ITEM")["QUANTITY"].sum().sort_values(ascending=False).head(5)

# %%
b.head(5)
# Out:
# ITEM
# PAROTTA             297.0
# DOSA                108.0
# CHAPPATHI            50.0
# KALAKI               49.0
# CHICKEN BIRIYANI     46.0
# Name: QUANTITY, dtype: float64

# %%
# To find the least sold item in 2.10.23
dt1=ds[ds["DATE"]=="2.10.2023"]
dt1.head()
# Out:
#           DATE   TIME  INVOICE_NO               ITEM  QUANTITY   RATE  \
# 259  2.10.2023  12.29           1   CHICKEN BIRIYANI       1.0  110.0
# 260  2.10.2023  12.32           2  CHICKEN FICE RICE       1.0  100.0
# 261  2.10.2023  12.32           2            GOBI 65       1.0   60.0
# 262  2.10.2023  12.32           2        EGG PAROTTA       1.0   70.0
# 263  2.10.2023  12.34           3            PAROTTA      12.0   18.0
#
#      SUB_TOTAL  AMOUNT  DAY
# 259      110.0   110.0    2
# 260      100.0   230.0    2
# 261       60.0     NaN    2
# 262       70.0     NaN    2
# 263      216.0   296.0    2

# %%
c=ds.groupby("ITEM")["QUANTITY"].sum().sort_values(ascending=True)

# %%
c.head()
# Out:
# ITEM
# MISCELLENOUS           0.0
# MISCELLE               0.0
# BOILED EGG             1.0
# BUCKET BIRIYNI HALF    1.0
# CHICKEN HYDERABAD      1.0
# Name: QUANTITY, dtype: float64

# %%
# To find the top 5 highest bill
d=ds.groupby("INVOICE_NO")["AMOUNT"].sum().sort_values(ascending=False)

# %%
d.head()
# Out:
# INVOICE_NO
# 63     941.0
# 68     892.0
# 66     835.0
# 58     808.0
# 159    768.0
# Name: AMOUNT, dtype: float64

# %%
# To find the no.of porotta sold in 1.10.23
dt2=ds[ds["DATE"]=="01.10.23"]

# %%
time = dt2[(dt2["TIME"] >= 18.00) & (dt2["TIME"] <= 21.00)]

# %%
time.head(10)
# Out:
#         DATE   TIME  INVOICE_NO                 ITEM  QUANTITY   RATE  \
# 8   01.10.23  19.42         101          BUN PAROTTA       3.0   25.0
# 9   01.10.23  19.42         101            VEG PULAV       1.0   85.0
# 10  01.10.23  20.42         123            CHAPPATHI       2.0   18.0
# 11  01.10.23  20.42         123              OMLETTE       1.0   18.0
# 12  01.10.23  19.53         106                 DOSA       2.0   20.0
# 66  01.10.23  20.53         124       GILMA BIRIYANI       1.0  130.0
# 67  01.10.23  20.53         124          BUN PAROTTA       4.0   25.0
# 68  01.10.23  20.53         124     PRAWN PEPPER FRY       1.0  140.0
# 69  01.10.23  20.53         124  MUSHROOM PEPPER FRY       1.0   90.0
# 70  01.10.23  20.53         124               KALAKI       3.0   15.0
#
#     SUB_TOTAL  AMOUNT  DAY
# 8        75.0     NaN    1
# 9        85.0   160.0    1
# 10       36.0     NaN    1
# 11       18.0    54.0    1
# 12       40.0    40.0    1
# 66      130.0     NaN    1
# ...

# %%
dt3=time[time["ITEM"]=="PAROTTA"]

# %%
dt3.head()
# Out:
#         DATE   TIME  INVOICE_NO     ITEM  QUANTITY  RATE  SUB_TOTAL  AMOUNT  \
# 72  01.10.23  20.56         126  PAROTTA       5.0  18.0       90.0    90.0
# 85  01.10.23  20.19         114  PAROTTA       4.0  18.0       72.0    72.0
# 87  01.10.23  20.10         110  PAROTTA       2.0  18.0       36.0     NaN
# 89  01.10.23  20.09         109  PAROTTA       2.0  18.0       36.0     NaN
# 92  01.10.23  20.02         108  PAROTTA       5.0  18.0       90.0     NaN
#
#     DAY
# 72    1
# 85    1
# 87    1
# 89    1
# 92    1

# %%
p=dt3.groupby("ITEM")["QUANTITY"].sum()
p.head()
# Out:
# ITEM
# PAROTTA    34.0
# Name: QUANTITY, dtype: float64

# %%
sns.barplot(time)
# Out:
# <Axes: >
