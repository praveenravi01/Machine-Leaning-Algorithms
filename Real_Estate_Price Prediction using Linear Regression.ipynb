# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ds=pd.read_csv("real_estate_price_size.csv")
ds
# Out:
#          price     size
# 0   234314.144   643.09
# 1   228581.528   656.22
# 2   281626.336   487.29
# 3   401255.608  1504.75
# 4   458674.256  1275.46
# ..         ...      ...
# 95  252460.400   549.80
# 96  310522.592  1037.44
# 97  383635.568  1504.75
# 98  225145.248   648.29
# 99  274922.856   705.29
#
# [100 rows x 2 columns]

# %%
sns.scatterplot(ds)
# Out:
# <Axes: >

# %%
ds.isnull().sum()
# Out:
# price    0
# size     0
# dtype: int64

# %%
x=ds["price"]
y=ds["size"]
plt.scatter(y,x)

# %%
x=ds[["size"]]
y=ds[["price"]]
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
clf=LinearRegression().fit(x,y)
clf.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(clf.intercept_)
print(clf.coef_)
# Out:
# [104769.58663143]
# [[216.2530156]]

# %%
y_pred=clf.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r_squared=r2_score(y_test,y_pred)
r_squared
# Out:
# 0.6921167959760717

# %%
print(clf.predict([[1379.72],[694]]))
# Out:
# [[403138.19731056]
#  [254849.17945557]]
# C:\Users\ravip\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
plt.scatter(x_train,y_train,color='b')
plt.plot(x_test,y_pred,color='r')

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error
mae=mean_absolute_error(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)
rmse=np.sqrt(mean_squared_error(y_test,y_pred))

# %%
print(mae)
print(mse)
print(rmse)
# Out:
# 38758.039080151866
# 2217832449.4284487
# 47093.86849079664
